# %%
import math
import os
import random
import re
import sys
import seaborn as sns
import matplotlib.pyplot as plt

# %%
array = [2.48, 2.75, 2.68, 2.66, 2.57, 2.74, 2.65, 2.82, 2.83, 2.62, 2.75, 2.69, 2.51,
3.42,  2.67, 2.67, 2.54, 2.66, 3.75, 2.46, 2.68, 2.57, 2.99, 2.62, 2.63 ];

# %%
figsize = (20,16)
sns.kdeplot(array, shade=True)
plt.xlabel('Data', Fontsize = 14)
plt.ylabel('Occurences', Fontsize = 14)
# Out:
# Text(0,0.5,'Occurences')
